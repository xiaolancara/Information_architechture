# %%
import pandas as pd
import boto3
from botocore.exceptions import ClientError

# %% [markdown]
# ### Part I: Takes the classic mushroom data set and loads it into pandas

# %%
df_mushroom = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/mushrooms.csv')
df_mushroom.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# ### Part 2: Create an s3 bucket for that file

# %%
region = 'us-east-1'
bucket_name = 'information-arch-xiaolanli-assignment-8a'
s3_client = boto3.client('s3', region_name=region, 
                         aws_access_key_id='AKIARHVK4WPTUEG4DEV7', 
                         aws_secret_access_key='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')
s3_client.create_bucket(Bucket=bucket_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'FESYZE18TSYR7EE1',
#   'HostId': 'GrpzGERmoEtXWU8INTsb2ioOMeppnwVcueFgj7jvTIiwWIXBD0SubuLbQYfDXJCOVKNzAWWOYdY=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'GrpzGERmoEtXWU8INTsb2ioOMeppnwVcueFgj7jvTIiwWIXBD0SubuLbQYfDXJCOVKNzAWWOYdY=',
#    'x-amz-request-id': 'FESYZE18TSYR7EE1',
#    'date': 'Sat, 17 Jul 2021 19:38:55 GMT',
#    'location': '/information-arch-xiaolanli-assignment-8a',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': '/information-arch-xiaolanli-assignment-8a'}

# %% [markdown]
# ### Part 3: Upload file to s3 bucket

# %%
fileName = 'mushroom.csv'
df_mushroom.to_csv(fileName, index=False)
s3_client.upload_file(fileName, bucket_name, fileName)
print('Upload completed')
# Out:
# Upload completed

# %% [markdown]
# ### Part 4: Output a confirmation that file is on s3 bucket

# %%
# read file from S3 bucket
obj = s3_client.get_object(Bucket=bucket_name,Key=fileName)
df_data = pd.read_csv(obj['Body'])
df_data
# Out:
#      type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0       p         x           s         n       t    p               f
# 1       e         x           s         y       t    a               f
# 2       e         b           s         w       t    l               f
# 3       p         x           y         w       t    p               f
# 4       e         x           s         g       f    n               f
# ...   ...       ...         ...       ...     ...  ...             ...
# 8119    e         k           s         n       f    n               a
# 8120    e         x           s         n       f    n               a
# 8121    e         f           s         n       f    n               a
# 8122    p         k           y         n       f    y               f
# 8123    e         x           s         n       f    n               a
#
#      gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# ...
